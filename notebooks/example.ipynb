# %%
# %load_ext autoreload
# %autoreload 2
import sys
import yaml
sys.path.append('../src')
from tsvae.utils.logger_utils import get_console_logger
logger = get_console_logger(__name__)
from os import path as pt

# %%
from experiments.experiment_utils import get_output_dir, update_config
from tsvae.dataset.data_pipeline import DataPipeline
from tsvae.models.network_pipeline import NetworkPipeline
from tsvae.utils.random_utils import set_seed


base_output_dir = '..' 
new_config = {'epochs' : 100, 'wandb': False, 'comment': 'test'}
exp_config_path = '../configs/BSprice/betacvae.yaml'

with open(exp_config_path) as file:
    exp_config = dict(yaml.safe_load(file))

exp_config = update_config(exp_config, new_config)

exp_config.base_output_dir = base_output_dir
exp_config.output_dir = get_output_dir(exp_config)
logger.info(f"Experiment results saved to {exp_config.output_dir}")

logger.info(f"Saving experiment config to {exp_config.output_dir}")
config_file_path = pt.join(exp_config.output_dir, "exp_config.yaml")
with open(config_file_path, "w") as outfile:
    yaml.dump(exp_config, outfile, default_flow_style=False)
# logger.info(exp_config)

# Generating data
logger.info(f"Setting ramdom seed: {exp_config.seed}")
set_seed(exp_config.seed)
# Out:
# Experiment results saved to ../results/BSprice_timestep_60/model_BetaCVAE_De_CLSTMRes_En_CLSTMRes_Prior_RealNVP_Con_Id_Dis_None_comment_test
# Saving experiment config to ../results/BSprice_timestep_60/model_BetaCVAE_De_CLSTMRes_En_CLSTMRes_Prior_RealNVP_Con_Id_Dis_None_comment_test
# Setting ramdom seed: 0

# %%
logger.info(f"Loading dataset: {exp_config.dataset}")
data_pipeline = DataPipeline()
train_dataset, eval_dataset = data_pipeline(exp_config)

# Loading network
logger.info("Load networks:")
network_pipeline = NetworkPipeline()
model = network_pipeline(exp_config)
# logger.info(f"{model}")
# Out:
# Loading dataset: BSprice
# Base dataset initialized
# Load networks:

# %%
from tsvae.trainers.base_trainer_config import BaseTrainerConfig
from tsvae.trainers.training_pipeline import TrainingPipeline


training_config = BaseTrainerConfig(
    output_dir=exp_config.output_dir,
    learning_rate=exp_config.lr,
    per_device_train_batch_size=exp_config.train_batch_size,
    per_device_eval_batch_size=exp_config.eval_batch_size,
    optimizer_cls=exp_config.optimizer,
    optimizer_params=None,
    scheduler_cls=None,
    scheduler_params=None,
    steps_saving=exp_config.steps_saving,
    steps_predict=exp_config.steps_predict,
    seed=exp_config.seed,
    num_epochs=exp_config.epochs,
    wandb_callback=exp_config.wandb,
    wandb_output_dir=exp_config.base_output_dir + "/wandb",
)

train_pipeline = TrainingPipeline(model=model, training_config=training_config, exp_config=exp_config)

trainer = train_pipeline(
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    device_name=exp_config.device_name,
)
# Out:
# Path Visualization of data
# Model passed sanity check !
# Ready for training.

# %%
train_pipeline.train(log_output=True)
# Out:
# Created ../results/BSprice_timestep_60/model_BetaCVAE_De_CLSTMRes_En_CLSTMRes_Prior_RealNVP_Con_Id_Dis_None_comment_test/BetaCVAE_training_2024-11-03_15-32-41.
# Training config, checkpoints and final model will be saved here.
#
# Training params:
#  - max_epochs: 100
#  - per_device_train_batch_size: 256
#  - per_device_eval_batch_size: 256
#  - checkpoint saving every: 20
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Scheduler: None
# Device: cpu
#
# Successfully launched training !
#
# Training of epoch 1/100:  90%|█████████ | 9/10 [00:00<00:00, 14.86batch/s]total loss: 40.46
# recon: 40.38
# reg: 1.95
# Training of epoch 1/100: 100%|██████████| 10/10 [00:00<00:00, 11.80batch/s]
# Eval of epoch 1/100:  10%|█         | 1/10 [00:00<00:01,  6.39batch/s]
# --------------------------------------------------------------------------
# Train loss: 61.1425
# --------------------------------------------------------------------------
# Training of epoch 2/100: 100%|██████████| 10/10 [00:00<00:00, 16.37batch/s]total loss: 30.03
# recon: 29.97
# reg: 1.60
# Training of epoch 2/100: 100%|██████████| 10/10 [00:00<00:00, 13.08batch/s]
# Eval of epoch 2/100:  10%|█         | 1/10 [00:00<00:01,  6.56batch/s]
# --------------------------------------------------------------------------
# Train loss: 32.6305
# --------------------------------------------------------------------------
# Training of epoch 3/100: 100%|██████████| 10/10 [00:00<00:00, 14.21batch/s]total loss: 24.89
# recon: 24.82
# reg: 1.66
# Training of epoch 3/100: 100%|██████████| 10/10 [00:00<00:00, 11.79batch/s]
# Eval of epoch 3/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 27.5785
# --------------------------------------------------------------------------
# Training of epoch 4/100: 100%|██████████| 10/10 [00:00<00:00, 14.29batch/s]total loss: 22.69
# recon: 22.64
# reg: 1.36
# Training of epoch 4/100: 100%|██████████| 10/10 [00:00<00:00, 11.33batch/s]
# Eval of epoch 4/100:  10%|█         | 1/10 [00:00<00:01,  5.36batch/s]
# --------------------------------------------------------------------------
# Train loss: 23.6655
# --------------------------------------------------------------------------
# Training of epoch 5/100: 100%|██████████| 10/10 [00:00<00:00, 15.50batch/s]total loss: 21.23
# recon: 21.17
# reg: 1.40
# Training of epoch 5/100: 100%|██████████| 10/10 [00:00<00:00, 11.99batch/s]
# Eval of epoch 5/100:  10%|█         | 1/10 [00:00<00:01,  6.63batch/s]
# --------------------------------------------------------------------------
# Train loss: 22.0152
# --------------------------------------------------------------------------
# Training of epoch 6/100: 100%|██████████| 10/10 [00:00<00:00, 16.39batch/s]total loss: 20.10
# recon: 20.07
# reg: 0.74
# Training of epoch 6/100: 100%|██████████| 10/10 [00:00<00:00, 13.02batch/s]
# Eval of epoch 6/100:  10%|█         | 1/10 [00:00<00:01,  6.48batch/s]
# --------------------------------------------------------------------------
# Train loss: 21.0064
# --------------------------------------------------------------------------
# Training of epoch 7/100: 100%|██████████| 10/10 [00:00<00:00, 16.37batch/s]total loss: 19.29
# recon: 19.21
# reg: 2.18
# Training of epoch 7/100: 100%|██████████| 10/10 [00:00<00:00, 13.10batch/s]
# Eval of epoch 7/100:  10%|█         | 1/10 [00:00<00:01,  6.77batch/s]
# --------------------------------------------------------------------------
# Train loss: 20.2612
# --------------------------------------------------------------------------
# Training of epoch 8/100: 100%|██████████| 10/10 [00:00<00:00, 12.25batch/s]total loss: 17.84
# recon: 17.66
# reg: 4.38
# Training of epoch 8/100: 100%|██████████| 10/10 [00:00<00:00, 10.48batch/s]
# Eval of epoch 8/100:  10%|█         | 1/10 [00:00<00:01,  6.15batch/s]
# --------------------------------------------------------------------------
# Train loss: 18.8913
# --------------------------------------------------------------------------
# Training of epoch 9/100: 100%|██████████| 10/10 [00:00<00:00, 15.38batch/s]total loss: 15.13
# recon: 14.74
# reg: 9.57
# Training of epoch 9/100: 100%|██████████| 10/10 [00:00<00:00, 12.09batch/s]
# Eval of epoch 9/100:  10%|█         | 1/10 [00:00<00:01,  5.79batch/s]
# --------------------------------------------------------------------------
# Train loss: 16.1177
# --------------------------------------------------------------------------
# Training of epoch 10/100: 100%|██████████| 10/10 [00:00<00:00, 14.98batch/s]total loss: 13.32
# recon: 12.96
# reg: 8.90
# Training of epoch 10/100: 100%|██████████| 10/10 [00:00<00:00, 12.01batch/s]
# Eval of epoch 10/100:  10%|█         | 1/10 [00:00<00:01,  6.03batch/s]
# --------------------------------------------------------------------------
# Train loss: 14.0564
# --------------------------------------------------------------------------
# Training of epoch 11/100: 100%|██████████| 10/10 [00:00<00:00, 15.23batch/s]total loss: 11.26
# recon: 10.87
# reg: 9.85
# Training of epoch 11/100: 100%|██████████| 10/10 [00:00<00:00, 12.10batch/s]
# Eval of epoch 11/100:  10%|█         | 1/10 [00:00<00:01,  6.13batch/s]
# --------------------------------------------------------------------------
# Train loss: 12.2718
# --------------------------------------------------------------------------
# Training of epoch 12/100: 100%|██████████| 10/10 [00:00<00:00, 15.15batch/s]total loss: 10.52
# recon: 10.07
# reg: 11.19
# Training of epoch 12/100: 100%|██████████| 10/10 [00:00<00:00, 11.58batch/s]
# Eval of epoch 12/100:  10%|█         | 1/10 [00:00<00:01,  5.43batch/s]
# --------------------------------------------------------------------------
# Train loss: 10.7928
# --------------------------------------------------------------------------
# Training of epoch 13/100: 100%|██████████| 10/10 [00:00<00:00, 15.99batch/s]total loss: 9.29
# recon: 8.75
# reg: 13.53
# Training of epoch 13/100: 100%|██████████| 10/10 [00:00<00:00, 12.75batch/s]
# Eval of epoch 13/100:  10%|█         | 1/10 [00:00<00:01,  6.27batch/s]
# --------------------------------------------------------------------------
# Train loss: 9.7447
# --------------------------------------------------------------------------
# Training of epoch 14/100: 100%|██████████| 10/10 [00:00<00:00, 16.19batch/s]total loss: 8.59
# recon: 8.00
# reg: 14.70
# Training of epoch 14/100: 100%|██████████| 10/10 [00:00<00:00, 12.97batch/s]
# Eval of epoch 14/100:  10%|█         | 1/10 [00:00<00:01,  6.69batch/s]
# --------------------------------------------------------------------------
# Train loss: 8.9843
# --------------------------------------------------------------------------
# Training of epoch 15/100: 100%|██████████| 10/10 [00:00<00:00, 16.28batch/s]total loss: 8.25
# recon: 7.60
# reg: 16.35
# Training of epoch 15/100: 100%|██████████| 10/10 [00:00<00:00, 12.85batch/s]
# Eval of epoch 15/100:  10%|█         | 1/10 [00:00<00:01,  6.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 8.5002
# --------------------------------------------------------------------------
# Training of epoch 16/100: 100%|██████████| 10/10 [00:00<00:00, 15.84batch/s]total loss: 7.57
# recon: 6.88
# reg: 17.07
# Training of epoch 16/100: 100%|██████████| 10/10 [00:00<00:00, 12.57batch/s]
# Eval of epoch 16/100:  10%|█         | 1/10 [00:00<00:01,  6.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 7.9463
# --------------------------------------------------------------------------
# Training of epoch 17/100: 100%|██████████| 10/10 [00:00<00:00, 16.07batch/s]total loss: 7.17
# recon: 6.46
# reg: 17.89
# Training of epoch 17/100: 100%|██████████| 10/10 [00:00<00:00, 12.79batch/s]
# Eval of epoch 17/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 7.5313
# --------------------------------------------------------------------------
# Training of epoch 18/100: 100%|██████████| 10/10 [00:00<00:00, 14.78batch/s]total loss: 6.69
# recon: 5.94
# reg: 18.73
# Training of epoch 18/100: 100%|██████████| 10/10 [00:00<00:00, 12.09batch/s]
# Eval of epoch 18/100:  10%|█         | 1/10 [00:00<00:01,  6.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 7.2071
# --------------------------------------------------------------------------
# Training of epoch 19/100: 100%|██████████| 10/10 [00:00<00:00, 15.32batch/s]total loss: 6.63
# recon: 5.82
# reg: 20.29
# Training of epoch 19/100: 100%|██████████| 10/10 [00:00<00:00, 11.55batch/s]
# Eval of epoch 19/100:  10%|█         | 1/10 [00:00<00:01,  5.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 6.8953
# --------------------------------------------------------------------------
# Training of epoch 20/100: 100%|██████████| 10/10 [00:00<00:00, 16.06batch/s]total loss: 6.53
# recon: 5.62
# reg: 22.68
# Training of epoch 20/100: 100%|██████████| 10/10 [00:00<00:00, 11.27batch/s]
# Eval of epoch 20/100:  10%|█         | 1/10 [00:00<00:02,  3.82batch/s]
# Saved checkpoint at epoch 20
#
# --------------------------------------------------------------------------
# Train loss: 6.6492
# --------------------------------------------------------------------------
# Training of epoch 21/100: 100%|██████████| 10/10 [00:00<00:00, 15.17batch/s]total loss: 6.36
# recon: 5.46
# reg: 22.50
# Training of epoch 21/100: 100%|██████████| 10/10 [00:00<00:00, 12.13batch/s]
# Eval of epoch 21/100:  10%|█         | 1/10 [00:00<00:01,  6.58batch/s]
# --------------------------------------------------------------------------
# Train loss: 6.3827
# --------------------------------------------------------------------------
# Training of epoch 22/100: 100%|██████████| 10/10 [00:00<00:00, 16.24batch/s]total loss: 6.20
# recon: 5.22
# reg: 24.41
# Training of epoch 22/100: 100%|██████████| 10/10 [00:00<00:00, 12.38batch/s]
# Eval of epoch 22/100:  10%|█         | 1/10 [00:00<00:01,  5.35batch/s]
# --------------------------------------------------------------------------
# Train loss: 6.1336
# --------------------------------------------------------------------------
# Training of epoch 23/100: 100%|██████████| 10/10 [00:00<00:00, 16.24batch/s]total loss: 5.89
# recon: 4.89
# reg: 25.06
# Training of epoch 23/100: 100%|██████████| 10/10 [00:00<00:00, 12.85batch/s]
# Eval of epoch 23/100:  10%|█         | 1/10 [00:00<00:01,  6.45batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.9621
# --------------------------------------------------------------------------
# Training of epoch 24/100: 100%|██████████| 10/10 [00:00<00:00, 15.80batch/s]total loss: 5.63
# recon: 4.55
# reg: 26.88
# Training of epoch 24/100: 100%|██████████| 10/10 [00:00<00:00, 12.55batch/s]
# Eval of epoch 24/100:  10%|█         | 1/10 [00:00<00:01,  6.59batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.8072
# --------------------------------------------------------------------------
# Training of epoch 25/100: 100%|██████████| 10/10 [00:00<00:00, 16.09batch/s]total loss: 5.62
# recon: 4.49
# reg: 28.30
# Training of epoch 25/100: 100%|██████████| 10/10 [00:00<00:00, 12.49batch/s]
# Eval of epoch 25/100:  10%|█         | 1/10 [00:00<00:01,  5.66batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.6821
# --------------------------------------------------------------------------
# Training of epoch 26/100: 100%|██████████| 10/10 [00:00<00:00, 15.78batch/s]total loss: 5.47
# recon: 4.35
# reg: 28.15
# Training of epoch 26/100: 100%|██████████| 10/10 [00:00<00:00, 12.13batch/s]
# Eval of epoch 26/100:  10%|█         | 1/10 [00:00<00:01,  5.88batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.6019
# --------------------------------------------------------------------------
# Training of epoch 27/100: 100%|██████████| 10/10 [00:00<00:00, 15.95batch/s]total loss: 5.52
# recon: 4.32
# reg: 30.15
# Training of epoch 27/100: 100%|██████████| 10/10 [00:00<00:00, 12.71batch/s]
# Eval of epoch 27/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.4385
# --------------------------------------------------------------------------
# Training of epoch 28/100: 100%|██████████| 10/10 [00:00<00:00, 15.47batch/s]total loss: 5.23
# recon: 3.96
# reg: 31.68
# Training of epoch 28/100: 100%|██████████| 10/10 [00:00<00:00, 12.53batch/s]
# Eval of epoch 28/100:  10%|█         | 1/10 [00:00<00:01,  6.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.2952
# --------------------------------------------------------------------------
# Training of epoch 29/100: 100%|██████████| 10/10 [00:00<00:00, 14.58batch/s]total loss: 5.17
# recon: 3.89
# reg: 31.93
# Training of epoch 29/100: 100%|██████████| 10/10 [00:00<00:00, 12.09batch/s]
# Eval of epoch 29/100:  10%|█         | 1/10 [00:00<00:01,  6.34batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.2321
# --------------------------------------------------------------------------
# Training of epoch 30/100: 100%|██████████| 10/10 [00:00<00:00, 15.85batch/s]total loss: 5.11
# recon: 3.80
# reg: 32.67
# Training of epoch 30/100: 100%|██████████| 10/10 [00:00<00:00, 12.65batch/s]
# Eval of epoch 30/100:  10%|█         | 1/10 [00:00<00:01,  6.27batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.1473
# --------------------------------------------------------------------------
# Training of epoch 31/100: 100%|██████████| 10/10 [00:00<00:00, 16.21batch/s]total loss: 5.10
# recon: 3.70
# reg: 34.92
# Training of epoch 31/100: 100%|██████████| 10/10 [00:00<00:00, 13.07batch/s]
# Eval of epoch 31/100:  10%|█         | 1/10 [00:00<00:01,  6.83batch/s]
# --------------------------------------------------------------------------
# Train loss: 5.0429
# --------------------------------------------------------------------------
# Training of epoch 32/100: 100%|██████████| 10/10 [00:00<00:00, 15.80batch/s]total loss: 4.81
# recon: 3.47
# reg: 33.49
# Training of epoch 32/100: 100%|██████████| 10/10 [00:00<00:00, 12.14batch/s]
# Eval of epoch 32/100:  10%|█         | 1/10 [00:00<00:01,  6.26batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.9807
# --------------------------------------------------------------------------
# Training of epoch 33/100: 100%|██████████| 10/10 [00:00<00:00, 16.14batch/s]total loss: 4.74
# recon: 3.36
# reg: 34.43
# Training of epoch 33/100: 100%|██████████| 10/10 [00:00<00:00, 12.90batch/s]
# Eval of epoch 33/100:  10%|█         | 1/10 [00:00<00:01,  6.52batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.8841
# --------------------------------------------------------------------------
# Training of epoch 34/100: 100%|██████████| 10/10 [00:00<00:00, 15.93batch/s]total loss: 4.89
# recon: 3.46
# reg: 35.67
# Training of epoch 34/100: 100%|██████████| 10/10 [00:00<00:00, 12.49batch/s]
# Eval of epoch 34/100:  10%|█         | 1/10 [00:00<00:01,  5.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.8608
# --------------------------------------------------------------------------
# Training of epoch 35/100: 100%|██████████| 10/10 [00:00<00:00, 16.01batch/s]total loss: 4.89
# recon: 3.41
# reg: 37.01
# Training of epoch 35/100: 100%|██████████| 10/10 [00:00<00:00, 12.76batch/s]
# Eval of epoch 35/100:  10%|█         | 1/10 [00:00<00:01,  6.47batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.8485
# --------------------------------------------------------------------------
# Training of epoch 36/100: 100%|██████████| 10/10 [00:00<00:00, 15.57batch/s]total loss: 4.73
# recon: 3.20
# reg: 38.25
# Training of epoch 36/100: 100%|██████████| 10/10 [00:00<00:00, 12.20batch/s]
# Eval of epoch 36/100:  10%|█         | 1/10 [00:00<00:01,  6.50batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.7235
# --------------------------------------------------------------------------
# Training of epoch 37/100: 100%|██████████| 10/10 [00:00<00:00, 16.11batch/s]total loss: 4.80
# recon: 3.29
# reg: 37.75
# Training of epoch 37/100: 100%|██████████| 10/10 [00:00<00:00, 12.86batch/s]
# Eval of epoch 37/100:  10%|█         | 1/10 [00:00<00:01,  6.56batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.6933
# --------------------------------------------------------------------------
# Training of epoch 38/100: 100%|██████████| 10/10 [00:00<00:00, 16.05batch/s]total loss: 4.55
# recon: 3.07
# reg: 37.02
# Training of epoch 38/100: 100%|██████████| 10/10 [00:00<00:00, 12.88batch/s]
# Eval of epoch 38/100:  10%|█         | 1/10 [00:00<00:01,  6.58batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.6666
# --------------------------------------------------------------------------
# Training of epoch 39/100: 100%|██████████| 10/10 [00:00<00:00, 15.71batch/s]total loss: 4.52
# recon: 3.01
# reg: 37.96
# Training of epoch 39/100: 100%|██████████| 10/10 [00:00<00:00, 12.16batch/s]
# Eval of epoch 39/100:  10%|█         | 1/10 [00:00<00:01,  6.27batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.5983
# --------------------------------------------------------------------------
# Training of epoch 40/100: 100%|██████████| 10/10 [00:00<00:00, 16.00batch/s]total loss: 4.51
# recon: 2.96
# reg: 38.88
# Training of epoch 40/100: 100%|██████████| 10/10 [00:00<00:00, 10.35batch/s]
# Eval of epoch 40/100:  10%|█         | 1/10 [00:00<00:02,  3.01batch/s]
# Saved checkpoint at epoch 40
#
# --------------------------------------------------------------------------
# Train loss: 4.5548
# --------------------------------------------------------------------------
# Training of epoch 41/100: 100%|██████████| 10/10 [00:00<00:00, 16.13batch/s]total loss: 4.66
# recon: 3.06
# reg: 39.94
# Training of epoch 41/100: 100%|██████████| 10/10 [00:00<00:00, 12.78batch/s]
# Eval of epoch 41/100:  10%|█         | 1/10 [00:00<00:01,  6.33batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.5055
# --------------------------------------------------------------------------
# Training of epoch 42/100: 100%|██████████| 10/10 [00:00<00:00, 15.47batch/s]total loss: 4.33
# recon: 2.76
# reg: 39.35
# Training of epoch 42/100: 100%|██████████| 10/10 [00:00<00:00, 12.02batch/s]
# Eval of epoch 42/100:  10%|█         | 1/10 [00:00<00:01,  6.40batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.4561
# --------------------------------------------------------------------------
# Training of epoch 43/100: 100%|██████████| 10/10 [00:00<00:00, 15.87batch/s]total loss: 4.54
# recon: 2.90
# reg: 40.95
# Training of epoch 43/100: 100%|██████████| 10/10 [00:00<00:00, 12.55batch/s]
# Eval of epoch 43/100:  10%|█         | 1/10 [00:00<00:01,  6.26batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.4365
# --------------------------------------------------------------------------
# Training of epoch 44/100: 100%|██████████| 10/10 [00:00<00:00, 16.00batch/s]total loss: 4.58
# recon: 2.98
# reg: 40.03
# Training of epoch 44/100: 100%|██████████| 10/10 [00:00<00:00, 12.66batch/s]
# Eval of epoch 44/100:  10%|█         | 1/10 [00:00<00:01,  6.09batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.5092
# --------------------------------------------------------------------------
# Training of epoch 45/100: 100%|██████████| 10/10 [00:00<00:00, 14.51batch/s]total loss: 4.50
# recon: 2.86
# reg: 40.95
# Training of epoch 45/100: 100%|██████████| 10/10 [00:00<00:00, 11.04batch/s]
# Eval of epoch 45/100:  10%|█         | 1/10 [00:00<00:01,  6.32batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.487
# --------------------------------------------------------------------------
# Training of epoch 46/100: 100%|██████████| 10/10 [00:00<00:00, 15.32batch/s]total loss: 4.45
# recon: 2.78
# reg: 41.71
# Training of epoch 46/100: 100%|██████████| 10/10 [00:00<00:00, 12.43batch/s]
# Eval of epoch 46/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.4623
# --------------------------------------------------------------------------
# Training of epoch 47/100: 100%|██████████| 10/10 [00:00<00:00, 15.83batch/s]total loss: 4.42
# recon: 2.72
# reg: 42.41
# Training of epoch 47/100: 100%|██████████| 10/10 [00:00<00:00, 12.66batch/s]
# Eval of epoch 47/100:  10%|█         | 1/10 [00:00<00:01,  6.50batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3762
# --------------------------------------------------------------------------
# Training of epoch 48/100: 100%|██████████| 10/10 [00:00<00:00, 15.72batch/s]total loss: 4.25
# recon: 2.59
# reg: 41.47
# Training of epoch 48/100: 100%|██████████| 10/10 [00:00<00:00, 12.25batch/s]
# Eval of epoch 48/100:  10%|█         | 1/10 [00:00<00:01,  6.31batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3504
# --------------------------------------------------------------------------
# Training of epoch 49/100: 100%|██████████| 10/10 [00:00<00:00, 15.86batch/s]total loss: 4.32
# recon: 2.62
# reg: 42.58
# Training of epoch 49/100: 100%|██████████| 10/10 [00:00<00:00, 12.59batch/s]
# Eval of epoch 49/100:  10%|█         | 1/10 [00:00<00:01,  6.18batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3418
# --------------------------------------------------------------------------
# Training of epoch 50/100: 100%|██████████| 10/10 [00:00<00:00, 15.91batch/s]total loss: 4.48
# recon: 2.75
# reg: 43.24
# Training of epoch 50/100: 100%|██████████| 10/10 [00:00<00:00, 12.62batch/s]
# Eval of epoch 50/100:  10%|█         | 1/10 [00:00<00:01,  6.50batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3477
# --------------------------------------------------------------------------
# Training of epoch 51/100: 100%|██████████| 10/10 [00:00<00:00, 15.70batch/s]total loss: 4.35
# recon: 2.62
# reg: 43.34
# Training of epoch 51/100: 100%|██████████| 10/10 [00:00<00:00, 12.25batch/s]
# Eval of epoch 51/100:  10%|█         | 1/10 [00:00<00:01,  6.40batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3024
# --------------------------------------------------------------------------
# Training of epoch 52/100: 100%|██████████| 10/10 [00:00<00:00, 15.68batch/s]total loss: 4.24
# recon: 2.54
# reg: 42.49
# Training of epoch 52/100: 100%|██████████| 10/10 [00:00<00:00, 12.52batch/s]
# Eval of epoch 52/100:  10%|█         | 1/10 [00:00<00:01,  6.18batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.2908
# --------------------------------------------------------------------------
# Training of epoch 53/100: 100%|██████████| 10/10 [00:00<00:00, 15.84batch/s]total loss: 4.43
# recon: 2.67
# reg: 43.85
# Training of epoch 53/100: 100%|██████████| 10/10 [00:00<00:00, 12.64batch/s]
# Eval of epoch 53/100:  10%|█         | 1/10 [00:00<00:01,  6.50batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3389
# --------------------------------------------------------------------------
# Training of epoch 54/100: 100%|██████████| 10/10 [00:00<00:00, 15.68batch/s]total loss: 4.26
# recon: 2.52
# reg: 43.38
# Training of epoch 54/100: 100%|██████████| 10/10 [00:00<00:00, 12.28batch/s]
# Eval of epoch 54/100:  10%|█         | 1/10 [00:00<00:01,  6.35batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3107
# --------------------------------------------------------------------------
# Training of epoch 55/100: 100%|██████████| 10/10 [00:00<00:00, 15.96batch/s]total loss: 4.28
# recon: 2.53
# reg: 43.81
# Training of epoch 55/100: 100%|██████████| 10/10 [00:00<00:00, 12.69batch/s]
# Eval of epoch 55/100:  10%|█         | 1/10 [00:00<00:01,  6.57batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.2455
# --------------------------------------------------------------------------
# Training of epoch 56/100: 100%|██████████| 10/10 [00:00<00:00, 15.81batch/s]total loss: 4.28
# recon: 2.51
# reg: 44.06
# Training of epoch 56/100: 100%|██████████| 10/10 [00:00<00:00, 12.06batch/s]
# Eval of epoch 56/100:  10%|█         | 1/10 [00:00<00:01,  5.20batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.2694
# --------------------------------------------------------------------------
# Training of epoch 57/100: 100%|██████████| 10/10 [00:00<00:00, 16.22batch/s]total loss: 4.53
# recon: 2.74
# reg: 44.68
# Training of epoch 57/100: 100%|██████████| 10/10 [00:00<00:00, 12.71batch/s]
# Eval of epoch 57/100:  10%|█         | 1/10 [00:00<00:01,  6.14batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.3012
# --------------------------------------------------------------------------
# Training of epoch 58/100: 100%|██████████| 10/10 [00:00<00:00, 15.82batch/s]total loss: 4.22
# recon: 2.38
# reg: 45.89
# Training of epoch 58/100: 100%|██████████| 10/10 [00:00<00:00, 12.58batch/s]
# Eval of epoch 58/100:  10%|█         | 1/10 [00:00<00:01,  6.42batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.2843
# --------------------------------------------------------------------------
# Training of epoch 59/100: 100%|██████████| 10/10 [00:00<00:00, 15.38batch/s]total loss: 4.10
# recon: 2.38
# reg: 42.90
# Training of epoch 59/100: 100%|██████████| 10/10 [00:00<00:00, 12.25batch/s]
# Eval of epoch 59/100:  10%|█         | 1/10 [00:00<00:01,  6.56batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1941
# --------------------------------------------------------------------------
# Training of epoch 60/100: 100%|██████████| 10/10 [00:00<00:00, 15.85batch/s]total loss: 4.04
# recon: 2.32
# reg: 43.06
# Training of epoch 60/100: 100%|██████████| 10/10 [00:00<00:00, 11.06batch/s]
# Eval of epoch 60/100:  10%|█         | 1/10 [00:00<00:02,  3.71batch/s]
# Saved checkpoint at epoch 60
#
# --------------------------------------------------------------------------
# Train loss: 4.2004
# --------------------------------------------------------------------------
# Training of epoch 61/100: 100%|██████████| 10/10 [00:00<00:00, 14.86batch/s]total loss: 4.15
# recon: 2.40
# reg: 43.88
# Training of epoch 61/100: 100%|██████████| 10/10 [00:00<00:00, 11.11batch/s]
# Eval of epoch 61/100:  10%|█         | 1/10 [00:00<00:01,  5.42batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.229
# --------------------------------------------------------------------------
# Training of epoch 62/100: 100%|██████████| 10/10 [00:00<00:00, 16.20batch/s]total loss: 4.11
# recon: 2.34
# reg: 44.20
# Training of epoch 62/100: 100%|██████████| 10/10 [00:00<00:00, 12.74batch/s]
# Eval of epoch 62/100:  10%|█         | 1/10 [00:00<00:01,  6.29batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1607
# --------------------------------------------------------------------------
# Training of epoch 63/100: 100%|██████████| 10/10 [00:00<00:00, 16.33batch/s]total loss: 4.13
# recon: 2.37
# reg: 43.98
# Training of epoch 63/100: 100%|██████████| 10/10 [00:00<00:00, 12.94batch/s]
# Eval of epoch 63/100:  10%|█         | 1/10 [00:00<00:01,  6.49batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1451
# --------------------------------------------------------------------------
# Training of epoch 64/100: 100%|██████████| 10/10 [00:00<00:00, 15.40batch/s]total loss: 4.10
# recon: 2.31
# reg: 44.78
# Training of epoch 64/100: 100%|██████████| 10/10 [00:00<00:00, 12.27batch/s]
# Eval of epoch 64/100:  10%|█         | 1/10 [00:00<00:01,  6.58batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.138
# --------------------------------------------------------------------------
# Training of epoch 65/100: 100%|██████████| 10/10 [00:00<00:00, 15.65batch/s]total loss: 4.19
# recon: 2.39
# reg: 44.96
# Training of epoch 65/100: 100%|██████████| 10/10 [00:00<00:00, 12.53batch/s]
# Eval of epoch 65/100:  10%|█         | 1/10 [00:00<00:01,  6.40batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1284
# --------------------------------------------------------------------------
# Training of epoch 66/100: 100%|██████████| 10/10 [00:00<00:00, 16.09batch/s]total loss: 4.09
# recon: 2.32
# reg: 44.19
# Training of epoch 66/100: 100%|██████████| 10/10 [00:00<00:00, 12.27batch/s]
# Eval of epoch 66/100:  10%|█         | 1/10 [00:00<00:01,  5.27batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1147
# --------------------------------------------------------------------------
# Training of epoch 67/100: 100%|██████████| 10/10 [00:00<00:00, 16.25batch/s]total loss: 4.09
# recon: 2.31
# reg: 44.69
# Training of epoch 67/100: 100%|██████████| 10/10 [00:00<00:00, 12.98batch/s]
# Eval of epoch 67/100:  10%|█         | 1/10 [00:00<00:01,  6.48batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1424
# --------------------------------------------------------------------------
# Training of epoch 68/100: 100%|██████████| 10/10 [00:00<00:00, 16.20batch/s]total loss: 4.11
# recon: 2.32
# reg: 44.67
# Training of epoch 68/100: 100%|██████████| 10/10 [00:00<00:00, 12.86batch/s]
# Eval of epoch 68/100:  10%|█         | 1/10 [00:00<00:01,  6.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1062
# --------------------------------------------------------------------------
# Training of epoch 69/100: 100%|██████████| 10/10 [00:00<00:00, 15.73batch/s]total loss: 4.17
# recon: 2.37
# reg: 45.04
# Training of epoch 69/100: 100%|██████████| 10/10 [00:00<00:00, 12.33batch/s]
# Eval of epoch 69/100:  10%|█         | 1/10 [00:00<00:01,  6.51batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1225
# --------------------------------------------------------------------------
# Training of epoch 70/100: 100%|██████████| 10/10 [00:00<00:00, 16.15batch/s]total loss: 4.06
# recon: 2.26
# reg: 44.91
# Training of epoch 70/100: 100%|██████████| 10/10 [00:00<00:00, 12.71batch/s]
# Eval of epoch 70/100:  10%|█         | 1/10 [00:00<00:01,  6.00batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1054
# --------------------------------------------------------------------------
# Training of epoch 71/100: 100%|██████████| 10/10 [00:00<00:00, 16.20batch/s]total loss: 4.08
# recon: 2.28
# reg: 44.97
# Training of epoch 71/100: 100%|██████████| 10/10 [00:00<00:00, 12.34batch/s]
# Eval of epoch 71/100:  10%|█         | 1/10 [00:00<00:01,  5.23batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1043
# --------------------------------------------------------------------------
# Training of epoch 72/100: 100%|██████████| 10/10 [00:00<00:00, 16.42batch/s]total loss: 4.14
# recon: 2.32
# reg: 45.61
# Training of epoch 72/100: 100%|██████████| 10/10 [00:00<00:00, 13.04batch/s]
# Eval of epoch 72/100:  10%|█         | 1/10 [00:00<00:01,  6.57batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.1464
# --------------------------------------------------------------------------
# Training of epoch 73/100: 100%|██████████| 10/10 [00:00<00:00, 15.70batch/s]total loss: 4.09
# recon: 2.27
# reg: 45.48
# Training of epoch 73/100: 100%|██████████| 10/10 [00:00<00:00, 12.45batch/s]
# Eval of epoch 73/100:  10%|█         | 1/10 [00:00<00:01,  6.25batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.086
# --------------------------------------------------------------------------
# Training of epoch 74/100: 100%|██████████| 10/10 [00:00<00:00, 15.96batch/s]total loss: 4.02
# recon: 2.19
# reg: 45.82
# Training of epoch 74/100: 100%|██████████| 10/10 [00:00<00:00, 12.47batch/s]
# Eval of epoch 74/100:  10%|█         | 1/10 [00:00<00:01,  6.56batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0693
# --------------------------------------------------------------------------
# Training of epoch 75/100: 100%|██████████| 10/10 [00:00<00:00, 16.11batch/s]total loss: 4.08
# recon: 2.29
# reg: 44.52
# Training of epoch 75/100: 100%|██████████| 10/10 [00:00<00:00, 12.90batch/s]
# Eval of epoch 75/100:  10%|█         | 1/10 [00:00<00:01,  6.47batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.045
# --------------------------------------------------------------------------
# Training of epoch 76/100: 100%|██████████| 10/10 [00:00<00:00, 15.30batch/s]total loss: 4.05
# recon: 2.28
# reg: 44.27
# Training of epoch 76/100: 100%|██████████| 10/10 [00:00<00:00, 12.46batch/s]
# Eval of epoch 76/100:  10%|█         | 1/10 [00:00<00:01,  6.62batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.054
# --------------------------------------------------------------------------
# Training of epoch 77/100: 100%|██████████| 10/10 [00:00<00:00, 16.26batch/s]total loss: 4.09
# recon: 2.26
# reg: 45.76
# Training of epoch 77/100: 100%|██████████| 10/10 [00:00<00:00, 12.87batch/s]
# Eval of epoch 77/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0546
# --------------------------------------------------------------------------
# Training of epoch 78/100: 100%|██████████| 10/10 [00:00<00:00, 16.16batch/s]total loss: 4.06
# recon: 2.25
# reg: 45.13
# Training of epoch 78/100: 100%|██████████| 10/10 [00:00<00:00, 12.50batch/s]
# Eval of epoch 78/100:  10%|█         | 1/10 [00:00<00:01,  5.67batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0694
# --------------------------------------------------------------------------
# Training of epoch 79/100: 100%|██████████| 10/10 [00:00<00:00, 15.96batch/s]total loss: 4.00
# recon: 2.20
# reg: 44.82
# Training of epoch 79/100: 100%|██████████| 10/10 [00:00<00:00, 12.73batch/s]
# Eval of epoch 79/100:  10%|█         | 1/10 [00:00<00:01,  6.53batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.029
# --------------------------------------------------------------------------
# Training of epoch 80/100: 100%|██████████| 10/10 [00:00<00:00, 16.31batch/s]total loss: 4.18
# recon: 2.33
# reg: 46.48
# Training of epoch 80/100: 100%|██████████| 10/10 [00:00<00:00, 11.49batch/s]
# Eval of epoch 80/100:  10%|█         | 1/10 [00:00<00:02,  3.93batch/s]
# Saved checkpoint at epoch 80
#
# --------------------------------------------------------------------------
# Train loss: 4.0308
# --------------------------------------------------------------------------
# Training of epoch 81/100: 100%|██████████| 10/10 [00:00<00:00, 15.31batch/s]total loss: 3.92
# recon: 2.10
# reg: 45.43
# Training of epoch 81/100: 100%|██████████| 10/10 [00:00<00:00, 12.24batch/s]
# Eval of epoch 81/100:  10%|█         | 1/10 [00:00<00:01,  6.32batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0255
# --------------------------------------------------------------------------
# Training of epoch 82/100: 100%|██████████| 10/10 [00:00<00:00, 15.85batch/s]total loss: 4.03
# recon: 2.21
# reg: 45.39
# Training of epoch 82/100: 100%|██████████| 10/10 [00:00<00:00, 12.51batch/s]
# Eval of epoch 82/100:  10%|█         | 1/10 [00:00<00:01,  6.11batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0423
# --------------------------------------------------------------------------
# Training of epoch 83/100: 100%|██████████| 10/10 [00:00<00:00, 15.36batch/s]total loss: 4.01
# recon: 2.16
# reg: 46.10
# Training of epoch 83/100: 100%|██████████| 10/10 [00:00<00:00, 12.18batch/s]
# Eval of epoch 83/100:  10%|█         | 1/10 [00:00<00:01,  6.45batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0561
# --------------------------------------------------------------------------
# Training of epoch 84/100: 100%|██████████| 10/10 [00:00<00:00, 16.13batch/s]total loss: 3.92
# recon: 2.11
# reg: 45.21
# Training of epoch 84/100: 100%|██████████| 10/10 [00:00<00:00, 12.97batch/s]
# Eval of epoch 84/100:  10%|█         | 1/10 [00:00<00:01,  6.62batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0051
# --------------------------------------------------------------------------
# Training of epoch 85/100: 100%|██████████| 10/10 [00:00<00:00, 16.01batch/s]total loss: 3.95
# recon: 2.16
# reg: 44.81
# Training of epoch 85/100: 100%|██████████| 10/10 [00:00<00:00, 12.28batch/s]
# Eval of epoch 85/100:  10%|█         | 1/10 [00:00<00:01,  5.39batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0038
# --------------------------------------------------------------------------
# Training of epoch 86/100: 100%|██████████| 10/10 [00:00<00:00, 16.14batch/s]total loss: 3.99
# recon: 2.21
# reg: 44.43
# Training of epoch 86/100: 100%|██████████| 10/10 [00:00<00:00, 12.88batch/s]
# Eval of epoch 86/100:  10%|█         | 1/10 [00:00<00:01,  6.51batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0067
# --------------------------------------------------------------------------
# Training of epoch 87/100: 100%|██████████| 10/10 [00:00<00:00, 14.93batch/s]total loss: 4.04
# recon: 2.21
# reg: 45.77
# Training of epoch 87/100: 100%|██████████| 10/10 [00:00<00:00, 12.30batch/s]
# Eval of epoch 87/100:  10%|█         | 1/10 [00:00<00:01,  6.69batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0086
# --------------------------------------------------------------------------
# Training of epoch 88/100: 100%|██████████| 10/10 [00:00<00:00, 15.87batch/s]total loss: 3.90
# recon: 2.13
# reg: 44.25
# Training of epoch 88/100: 100%|██████████| 10/10 [00:00<00:00, 12.80batch/s]
# Eval of epoch 88/100:  10%|█         | 1/10 [00:00<00:01,  6.63batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9874
# --------------------------------------------------------------------------
# Training of epoch 89/100: 100%|██████████| 10/10 [00:00<00:00, 16.32batch/s]total loss: 3.94
# recon: 2.16
# reg: 44.39
# Training of epoch 89/100: 100%|██████████| 10/10 [00:00<00:00, 12.56batch/s]
# Eval of epoch 89/100:  10%|█         | 1/10 [00:00<00:01,  5.53batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0264
# --------------------------------------------------------------------------
# Training of epoch 90/100: 100%|██████████| 10/10 [00:00<00:00, 15.12batch/s]total loss: 4.00
# recon: 2.19
# reg: 45.25
# Training of epoch 90/100: 100%|██████████| 10/10 [00:00<00:00, 11.36batch/s]
# Eval of epoch 90/100:  10%|█         | 1/10 [00:00<00:01,  6.46batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0242
# --------------------------------------------------------------------------
# Training of epoch 91/100: 100%|██████████| 10/10 [00:00<00:00, 15.87batch/s]total loss: 4.05
# recon: 2.20
# reg: 46.28
# Training of epoch 91/100: 100%|██████████| 10/10 [00:00<00:00, 12.22batch/s]
# Eval of epoch 91/100:  10%|█         | 1/10 [00:00<00:01,  5.34batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9812
# --------------------------------------------------------------------------
# Training of epoch 92/100: 100%|██████████| 10/10 [00:00<00:00, 16.14batch/s]total loss: 4.04
# recon: 2.24
# reg: 44.92
# Training of epoch 92/100: 100%|██████████| 10/10 [00:00<00:00, 12.88batch/s]
# Eval of epoch 92/100:  10%|█         | 1/10 [00:00<00:01,  6.37batch/s]
# --------------------------------------------------------------------------
# Train loss: 4.0242
# --------------------------------------------------------------------------
# Training of epoch 93/100: 100%|██████████| 10/10 [00:00<00:00, 16.26batch/s]total loss: 3.99
# recon: 2.17
# reg: 45.47
# Training of epoch 93/100: 100%|██████████| 10/10 [00:00<00:00, 12.92batch/s]
# Eval of epoch 93/100:  10%|█         | 1/10 [00:00<00:01,  6.57batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9606
# --------------------------------------------------------------------------
# Training of epoch 94/100:  90%|█████████ | 9/10 [00:00<00:00, 15.40batch/s]total loss: 3.94
# recon: 2.16
# reg: 44.65
# Training of epoch 94/100: 100%|██████████| 10/10 [00:00<00:00, 11.59batch/s]
# Eval of epoch 94/100:  10%|█         | 1/10 [00:00<00:01,  5.26batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9567
# --------------------------------------------------------------------------
# Training of epoch 95/100: 100%|██████████| 10/10 [00:00<00:00, 15.62batch/s]total loss: 3.91
# recon: 2.12
# reg: 44.98
# Training of epoch 95/100: 100%|██████████| 10/10 [00:00<00:00, 12.49batch/s]
# Eval of epoch 95/100:  10%|█         | 1/10 [00:00<00:01,  6.72batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9738
# --------------------------------------------------------------------------
# Training of epoch 96/100: 100%|██████████| 10/10 [00:00<00:00, 15.74batch/s]total loss: 4.02
# recon: 2.16
# reg: 46.47
# Training of epoch 96/100: 100%|██████████| 10/10 [00:00<00:00, 12.40batch/s]
# Eval of epoch 96/100:  10%|█         | 1/10 [00:00<00:01,  6.65batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9725
# --------------------------------------------------------------------------
# Training of epoch 97/100: 100%|██████████| 10/10 [00:00<00:00, 16.42batch/s]total loss: 4.01
# recon: 2.19
# reg: 45.49
# Training of epoch 97/100: 100%|██████████| 10/10 [00:00<00:00, 13.08batch/s]
# Eval of epoch 97/100:  10%|█         | 1/10 [00:00<00:01,  6.47batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9354
# --------------------------------------------------------------------------
# Training of epoch 98/100: 100%|██████████| 10/10 [00:00<00:00, 15.01batch/s]total loss: 4.00
# recon: 2.18
# reg: 45.59
# Training of epoch 98/100: 100%|██████████| 10/10 [00:00<00:00, 11.98batch/s]
# Eval of epoch 98/100:  10%|█         | 1/10 [00:00<00:01,  6.21batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.9451
# --------------------------------------------------------------------------
# Training of epoch 99/100: 100%|██████████| 10/10 [00:00<00:00, 16.13batch/s]total loss: 4.00
# recon: 2.15
# reg: 46.34
# Training of epoch 99/100: 100%|██████████| 10/10 [00:00<00:00, 12.93batch/s]
# Eval of epoch 99/100:  10%|█         | 1/10 [00:00<00:01,  6.73batch/s]
# --------------------------------------------------------------------------
# Train loss: 3.945
# --------------------------------------------------------------------------
# Training of epoch 100/100: 100%|██████████| 10/10 [00:00<00:00, 16.01batch/s]total loss: 3.97
# recon: 2.15
# reg: 45.66
# Training of epoch 100/100: 100%|██████████| 10/10 [00:00<00:00, 11.05batch/s]
# Eval of epoch 100/100:  10%|█         | 1/10 [00:00<00:02,  3.88batch/s]
# Saved checkpoint at epoch 100
#
# --------------------------------------------------------------------------
# Train loss: 3.9445
# --------------------------------------------------------------------------
# Training ended!
# Saved final model in ../results/BSprice_timestep_60/model_BetaCVAE_De_CLSTMRes_En_CLSTMRes_Prior_RealNVP_Con_Id_Dis_None_comment_test/BetaCVAE_training_2024-11-03_15-32-41/final_model

# %%
from evaluations.hyperparameter import ModelEvaluator
from os import path as pt

model_dir = pt.join(trainer.training_dir, 'final_model')
model_evaluator = ModelEvaluator(model_dir)
output_dir = model_evaluator.hyper_model_dir
model = model_evaluator.model

test_data, gen_data, recon_data = model_evaluator.load_data(seed = 99)
ds = model_evaluator.data_ppl.base_dataset

real_data = test_data
recon_data = recon_data
fake_data = gen_data
# Out:
# Base dataset initialized

# %%
from evaluations.compare import compare_path
compare_path(real_data,fake_data)
